# %% [markdown]
# "A coluna 'Idade' tem 12% de valores em falta. O que queres fazer?
# 1 — Remover as linhas
# 2 — Preencher com um valor fixo
# 3 — Preencher com a média/mediana
# 4 — Deixar como está"
