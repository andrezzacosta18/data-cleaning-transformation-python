# %% [markdown]
# # Data Quality Analysis
#
# ## Netflix Titles Dataset
#
# ### Data Cleaning and Transformation Project
#
# ---
#
# **Course:** Data Analyst - Cleaning and Transformation with Python
#
# **Institution:** CESAE Digital
#
# **Team Members:**
#
# - Andreza Silva
# - Bruno Moller
# - Ilana Freire
#
# **Date:** July 2026

# %% [markdown]
# # Introduction
#
# Data quality assessment is a fundamental step in every data analytics project. Before cleaning or transforming data, it is essential to understand the dataset, evaluate its structure, and identify potential quality issues.
#
# This notebook presents an exploratory analysis of the **Netflix Titles** dataset. The objective is to assess its quality by examining its structure, identifying missing values, duplicate records, and potential inconsistencies that may affect future analyses.
#
# The insights obtained in this notebook will support the data cleaning and transformation stages developed in the next modules of the project.

# %% [markdown]
# # Objectives
#
# The main objectives of this analysis are:
#
# - Understand the dataset structure.
# - Explore the available variables.
# - Assess the overall data quality.
# - Identify missing values.
# - Detect duplicate records.
# - Analyse categorical and numerical variables.
# - Identify potential inconsistencies.
# - Support the data cleaning and transformation process.

# %% [markdown]
# # Objectives
#
# The main objectives of this analysis are:
#
# - Understand the dataset structure.
# - Explore the available variables.
# - Assess the overall data quality.
# - Identify missing values.
# - Detect duplicate records.
# - Analyse categorical and numerical variables.
# - Identify potential inconsistencies.
# - Support the data cleaning and transformation process.

# %%
import pandas as pd                  # Data manipulation and analysis
import numpy as np                   # Numerical computations
import matplotlib.pyplot as plt      # Data visualisation
from IPython.display import display  # Better DataFrame visualisation in Jupyter Notebook

# %% [markdown]
# # Load Dataset
#
# In this section, the dataset is loaded into the Python environment.
#
# Before starting the exploratory analysis, the project directory and the dataset path are defined to ensure that the file can be accessed correctly.

# %%
dataset_path = "../data/raw/netflix_titles.xlsx"
df = pd.read_excel(dataset_path)
